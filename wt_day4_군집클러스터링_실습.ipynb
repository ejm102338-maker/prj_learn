# %%
import pandas as pd
import numpy as np
import folium
from folium.plugins import MarkerCluster

# %%
df = pd.read_csv('./data/gangnam_starbuks.csv')
df.head()
# Out:
#    Unnamed: 0   Latitude   Longitude
# 0           0  37.500880  127.022626
# 1           1  37.497070  127.024239
# 2           2  37.501786  127.032084
# 3           3  37.507038  127.031262
# 4           4  37.496495  127.027475

# %%
df.info()
df.describe()
df.isna().sum()

# %%
df = df.drop("Unnamed: 0",axis=1)
df.head()
# Out:
#     Latitude   Longitude
# 0  37.500880  127.022626
# 1  37.497070  127.024239
# 2  37.501786  127.032084
# 3  37.507038  127.031262
# 4  37.496495  127.027475

# %%
center_lat = df["Latitude"].mean()
center_lon = df["Longitude"].mean()

# %%
gangnam_map = folium.Map(location = [center_lat,center_lon],zoom_start=13)

# %%
cluster = MarkerCluster().add_to(gangnam_map)

for _,row in df.iterrows():
    folium.CircleMarker(
        location = [row["Latitude"],row["Longitude"]],
        radius=3,
        fill=True,
        fill_opacity=0.8
    ).add_to(cluster)
    
    # print(location)
    # print("-"*30)

# %%
gangnam_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d435a51e470551908b92c200fb6aaf09 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d435a51e470551908b92c200fb6aaf09&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d435a51e470551908b92c200fb6aaf09 = L.map(
#                 &quot;map_d435a51e470551908b92c200fb6aaf09&quot;,
#                 {
#                     center: [37.50214990371332, 127.04984247339881],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5076d9047bfac7e3eb7d1b476c7c1dfc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5076d9047bfac7e3eb7d1b476c7c1dfc.addTo(map_d435a51e470551908b92c200fb6aaf09);
#
#
#             var marker_cluster_1e29705d7f02d40d605a01d7609b45be = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var circle_marker_04b62f417a7d9bc941b465b6352ec806 = L.circleMarker(
#                 [37.50088028491807, 127.02262602993449],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_1e29705d7f02d40d605a01d7609b45be);
#
#
#             var circle_marker_763cad93263b68be5f0903809ed2407a = L.circleMarker(
#                 [37.497070414192976, 127.02423891375882],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_1e29705d7f02d40d605a01d7609b45be);
#
#
#             var circle_marker_a0a35b037333dbfd30ab39dd99da2705 = L.circleMarker(
#                 [37.501786131228606, 127.03208376163074],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_1e29705d7f02d40d605a01d7609b45be);
#
#
#             var circle_marker_a64db81be61843e8afe525695318b8e7 = L.circleMarker(
#                 [37.50703817913845, 127.0312622215926],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(marker_cluster_1e29705d7f02d40d605a01d7609b45be);
#
#
#             var circle_marker_623e25fbc98381771897dd2ea46542be = L.circleMarker(
#                 [37.49649507975166, 127.02747459043624],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&qu

# %%
from sklearn.cluster import KMeans

kmeans_model = KMeans(n_clusters=5,random_state=3333)
kmeans_model.fit(df.iloc[:,0:2])
# Out:
# KMeans(n_clusters=5, random_state=3333)

# %%
print(df.iloc[:,0:2])
# Out:
#       Latitude   Longitude
# 0    37.500880  127.022626
# 1    37.497070  127.024239
# 2    37.501786  127.032084
# 3    37.507038  127.031262
# 4    37.496495  127.027475
# ..         ...         ...
# 995  37.484810  127.108791
# 996  37.485588  127.101114
# 997  37.498591  127.095127
# 998  37.491326  127.100159
# 999  37.485332  127.096086
#
# [1000 rows x 2 columns]

# %%
kmeans_model.labels_

df["cluster"] = kmeans_model.labels_

df.head(20)
# Out:
#      Latitude   Longitude  cluster
# 0   37.500880  127.022626        2
# 1   37.497070  127.024239        2
# 2   37.501786  127.032084        2
# 3   37.507038  127.031262        2
# 4   37.496495  127.027475        2
# 5   37.496495  127.028304        2
# 6   37.507375  127.035266        2
# 7   37.502505  127.024051        2
# 8   37.495083  127.030883        2
# 9   37.501155  127.026387        2
# 10  37.495119  127.026294        2
# 11  37.495106  127.034193        2
# 12  37.499352  127.032552        2
# 13  37.486420  127.032481        2
# 14  37.487550  127.035433        2
# 15  37.494526  127.027726        2
# 16  37.491823  127.031692        2
# 17  37.499785  127.025738        2
# 18  37.492452  127.029545        2
# 19  37.489426  127.026819        2

# %%
#test_cluster = [[37.496495,127.027475]]
test_cluster = [
    {
       "Latitude":37.496495,
        "Longitude" :127.027475 
    }
]
test_cluster[0]["Latitude"]
# Out:
# 37.496495

# %%
test_cluster[0]["Latitude"]
# Out:
# 37.496495

# %%
pred = kmeans_model.predict([[test_cluster[0]["Latitude"],test_cluster[0]["Longitude"]]])
pred
# Out:
# c:\potenup3\prj_learn\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# array([2], dtype=int32)

# %%
kmeans_model.cluster_centers_
# Out:
# array([[ 37.5276094 , 127.03795598],
#        [ 37.48994554, 127.05460982],
#        [ 37.49779446, 127.02723942],
#        [ 37.48705583, 127.10190646],
#        [ 37.51166628, 127.05985764]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,10))

sns.scatterplot(x='Longitude',y='Latitude',hue='cluster',data=df,palette='viridis',s=50,alpha=0.6,legend='full')
plt.scatter(kmeans_model.cluster_centers_[:,1],kmeans_model.cluster_centers_[:,0],s=300,c='red',marker='*')
plt.show()
